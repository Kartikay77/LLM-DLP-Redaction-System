# %%
from google.colab import drive
drive.mount('/content/drive')
import os, pprint
PROJECT_DIR = "/content/drive/MyDrive/DataShield_AI"
MODEL_DIR   = f"{PROJECT_DIR}/models/ner-distilbert"
print("Exists?", os.path.isdir(MODEL_DIR))
pprint.pp(os.listdir(MODEL_DIR))
# Out:
# Mounted at /content/drive
# Exists? True
# ['checkpoint-1126',
#  'checkpoint-1689',
#  'config.json',
#  'model.safetensors',
#  'special_tokens_map.json',
#  'vocab.txt',
#  'labels.json',
#  'training_args.bin',
#  'tokenizer.json',
#  'tokenizer_config.json']

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

drift = json.load(open(f"{MODEL_DIR}/drift_log.json"))
df = pd.json_normalize(drift, record_path=["distribution"], meta=["timestamp"])
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index("timestamp").plot(kind="line", figsize=(12,6))
plt.title("Entity Distribution Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1042850699.py in <cell line: 0>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 drift = json.load(open(f"{MODEL_DIR}/drift_log.json"))
#       6 df = pd.json_normalize(drift, record_path=["distribution"], meta=["timestamp"])
#       7 df['timestamp'] = pd.to_datetime(df['timestamp'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DataShield_AI/models/ner-distilbert/drift_log.json'
